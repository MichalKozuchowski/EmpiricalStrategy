# %% [markdown]
# # Install Packages
#
# Run this once per fresh JupyterLab session on the cluster (per Class 2 notes: keep a
# dedicated `installpackages` notebook in your home directory, reusable across sessions).
#
# Only install what you actually need for the task at hand — not Anaconda's full suite.

# %%
# Professor's canonical snippet (Class 2 slides) -- --user matters, you don't have
# write access outside your home directory on the shared cluster.
import sys
# !{sys.executable} -m pip install --user pandas matplotlib

# %% [markdown]
# Add more packages by rerunning the same pattern with a different module name
# (e.g. `numpy`, `scikit-learn`, `statsmodels`, `seaborn`).
